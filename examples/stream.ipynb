// %% [markdown]
// # Получение сообщений (стримингом)
// Source: [stream.ts](source/stream.ts)

// %%
import GigaChat from 'gigachat';
import * as dotenv from 'dotenv';
import { Agent } from 'node:https';

dotenv.config();

const httpsAgent = new Agent({
    rejectUnauthorized: false,
});

const client = new GigaChat({
    profanityCheck: false,
    timeout: 600,
    model: 'GigaChat-Pro',
    httpsAgent: httpsAgent,
});

// %%
let message = "";
for await (const chunk of client.stream('Напиши отчет на тему ипотечного кризиса')) {
    message += chunk.choices[0]?.delta.content;
}
message
// Out:
// "### Отчет: Анализ ипотечного кризиса\n" +
//   "\n" +
//   "#### Введение\n" +
//   "Ипотечный кризис — это экономический феномен, который возник в результате массового дефолта заемщиков по ипотечным кредитам, особенно в секторе субстандартного кредитования. Этот кризис оказал значительное влияние на мировую экономику, начиная с конца 2000-х годов, и стал одной из основных причин глобального финансового кризиса 2008 года. Цель данного отчета — проанализировать причины возникновения ипотечного кризиса, его последствия и уроки, которые были извлечены.\n" +
//   "\n" +
//   "#### Причины ипотечного кризиса\n" +
//   "1. **Субстандартное кредитование**: Банки начали активно выдавать кредиты людям с низким кредитным рейтингом (субстандартным заемщикам), предлагая им привлекательные условия ипотеки. Это привело к росту числа высокорисковых кредитов.\n" +
//   "   \n" +
//   "2. **Низкие процентные ставки**: ФРС США поддерживала низкие процентные ставки в течение длительного периода, что стимулировало заимствования и инвестиции, включая покупку недвижимости.\n" +
//   "\n" +
//   "3. **Дерегулирование финансовой системы**: Ослабление регулирования финансовых институтов позволило банкам создавать сложные финансовые продукты, такие как ипотечные ценные бумаги (MBS) и кредитные дефолтные свопы (CDS).\n" +
//   "\n" +
//   "4. **Спекуляции на рынке недвижимости**: Рост цен на недвижимость создал иллюзию стабильности и привел к спекуляциям на рынке, когда инвесторы покупали дома не для проживания, а с целью быстрой перепродажи.\n" +
//   "\n" +
//   "5. **Неправильная оценка рисков**: Кредиторы и рейтинговые агентства недооценивали риски, связанные с субстандартными кредитами, что привело к завышению оценок ипотечных ценных бумаг.\n" +
//   "\n" +
//   "#### Развитие кризиса\n" +
//   "1. **Рост невыплат по ипотеке**: Субстандартные заемщики начали массово прекращать выплаты по своим ипотечным кредитам, что вызвало волну дефолтов.\n" +
//   "\n" +
//   "2. **Обесценивание ипотечных ценных бумаг**: Инвесторы осознали, что многие активы, основанные на субстандартных ипотеках, имеют низкую ликвидность и высокий риск дефолта, что привело к падению стоимости этих активов.\n" +
//   "\n" +
//   "3. **Банкротство банков и финансовых учреждений**: Крупнейшие банки и инвестиционные компании, такие как Lehman Brothers, оказались на грани банкротства из-за больших объемов токсичных активов на своих балансах.\n" +
//   "\n" +
//   "4. **Глобализация кризиса**: Ипотечный кризис в США быстро распространился на другие страны через международные финансовые рынки, затронув экономики Европы, Азии и Латинской Америки.\n" +
//   "\n" +
//   "#### Последствия ипотечного кризиса\n" +
//   "1. **Экономический спад**: Мировая экономика погрузилась в глубокую рецессию, сопровождавшуюся снижением ВВП, ростом безработицы и сокращением потребительских расходов.\n" +
//   "\n" +
//   "2. **Финансовый стресс**: Многие банки столкнулись с нехваткой капитала и были вынуждены прибегнуть к государственной помощи. Система межбанковского кредитования практически остановилась.\n" +
//   "\n" +
//   "3. **Политические реформы**: Кризис привел к ужесточению регулирования банковской сферы, введению новых стандартов капитализации и усилению контроля над финансовыми рынками.\n" +
//   "\n" +
//   "4. **Социальные последствия**: Увеличение уровня бедности, рост числа бездомных и ухудшение качества жизни населения стали результатом экономического спада.\n" +
//   "\n" +
//   "#### Уроки ипотечного кризиса\n" +
//   "1. **Необходимость строгого регулирования**: Финансовая система нуждается в более жестком контроле и надзорных механизмах для предотвращения чрезмерных рисков.\n" +
//   "\n" +
//   "2. **Оценка реальных возможностей заемщиков**: Важно учитывать реальные доходы и возможности погашения кредита перед выдачей займов, особенно в сегменте субстандартного кредитования.\n" +
//   "\n" +
//   "3. **Прозрачность финансовых продуктов**: Создание прозрачных и понятных финансовых инструментов поможет избежать ситуаций, когда инвесторы неправильно оценивают риски.\n" +
//   "\n" +
//   "4. **Диверсификация экономики**: Зависимость от одного сектора экономики, такого как рынок недвижимости, делает систему уязвимой к резким изменениям. Диверсифицированная экономика менее подвержена кризисам.\n" +
//   "\n" +
//   "#### Заключение\n" +
//   "Ипотечный кризис 2007-2009 годов стал важным уроком для мировой финансовой системы. Он показал, насколько опасной может быть комбинация дерегуляции, высоких рисков и неправильной оценки активов. Однако благодаря этому кризису были предприняты значительные шаги по реформированию финансовой системы, направленные на предотвращение повторения подобных событий в будущем.\n" +
//   "\n" +
//   "---\n" +
//   "\n" +
//   "Этот отчет представляет собой обзор ключевых аспектов ипотечного кризиса и его последствий. Для более глубокого анализа рекомендуется изучить дополнительные источники и исследования."
